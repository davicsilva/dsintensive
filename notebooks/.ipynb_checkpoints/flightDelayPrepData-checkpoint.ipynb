# %% [markdown]
# # Flight delays (capstone project)
# # Data wrangling (kind of), some dataset merge process etc...

# %%
# date lib
from datetime import datetime

# Pandas and NumPy
import pandas as pd
import numpy as np

# %%
# 1. Flight delay: any flight with (real_departure - planned_departure >= 15 minutes)
# 2. The Brazilian Federal Agency for Civil Aviation (ANAC) does not define exactly what is a "flight delay" (in minutes)
# 3. Anyway, the ANAC has a resolution for this subject: https://goo.gl/YBwbMy (last access: nov, 15th, 2017)
# ---
# DELAY, for this analysis, is defined as greater than 15 minutes (local flights only)
DELAY = 15

# %% [markdown]
# ### Local flights dataset. For now, only flights from jan to sep, 2017...
#
# **A note about date columns on this dataset**
# * In the original dataset (CSV file from ANAC), the date was not in ISO8601 format (e.g. '2017-10-31 09:03:00')
# * To fix this I used regex (regular expression) to transform this column directly on CSV file
# * The original date was "31/10/2017 09:03" (october, 31, 2017 09:03)
#
# **The regex**:
# * find dates with
# "**([0-9]{2})/([0-9]{2})/([0-9]{4}) ([0-9]{2}):([0-9]{2})**", and
# * replace with
# "**\3-\2-\1 \4:\5:00**"

# %%
#[flights] dataset_01 => all "Active Regular Flights" from 2017, from january to september
#source: http://www.anac.gov.br/assuntos/dados-e-estatisticas/historico-de-voos
#Last access this website: nov, 14th, 2017
flights = pd.read_csv('data/arf2017ISO.csv', sep = ';', parse_dates = True)

# %%
flights.head()
# Out:
#   airline  flightcode authcode linecode airportA airportB        departureest  \
# 0     AAL         213        0        I     KMIA     SBBR 2017-01-02 01:20:00
# 1     AAL         213        0        I     KMIA     SBBR 2017-01-24 01:20:00
# 2     AAL         213        0        I     KMIA     SBBR 2017-01-29 01:20:00
# 3     AAL         213        0        I     KMIA     SBBR 2017-01-23 01:20:00
# 4     AAL         213        0        I     KMIA     SBBR 2017-01-25 01:20:00
#
#         departurereal          arrivalest         arrivalreal flightstatus  \
# 0 2017-01-02 01:20:00 2017-01-02 09:00:00 2017-01-02 09:00:00    REALIZADO
# 1 2017-01-24 01:20:00 2017-01-24 09:00:00 2017-01-24 09:00:00    REALIZADO
# 2 2017-01-29 01:20:00 2017-01-29 09:00:00 2017-01-29 09:00:00    REALIZADO
# 3 2017-01-23 01:20:00 2017-01-23 09:00:00 2017-01-23 09:00:00    REALIZADO
# 4 2017-01-25 01:20:00 2017-01-25 09:00:00 2017-01-25 09:00:00    REALIZADO
#
#   problemcode
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
# Airports four-letters-code from object to string
flights['airportA'] = flights['airportA'].astype('str')
flights['airportB'] = flights['airportB'].astype('str')

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 820958 entries, 0 to 820957
# Data columns (total 12 columns):
# airline          820958 non-null object
# flightcode       820958 non-null int64
# authcode         820958 non-null object
# linecode         820958 non-null object
# airportA         820958 non-null object
# airportB         820958 non-null object
# departureest     773887 non-null object
# departurereal    738514 non-null object
# arrivalest       773887 non-null object
# arrivalreal      738513 non-null object
# flightstatus     820958 non-null object
# problemcode      302784 non-null object
# dtypes: int64(1), object(11)
# memory usage: 75.2+ MB

# %% [markdown]
# ### Local airports (list with all the ~600 brazilian public airports)
#
# Source: https://goo.gl/mNFuPt (a XLS spreadsheet in portuguese; last access on nov, 15th, 2017)

# %%
# Airports dataset: all brazilian public airports (updated until october, 2017)
airports = pd.read_csv('data/brazilianPublicAirports-out2017.csv', sep = ';')

# %%
airports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 589 entries, 0 to 588
# Data columns (total 8 columns):
# airport        589 non-null object
# airportname    589 non-null object
# city           589 non-null object
# state          589 non-null object
# latitude       589 non-null object
# longitude      589 non-null object
# altitude       589 non-null object
# operation      589 non-null object
# dtypes: object(8)
# memory usage: 36.9+ KB

# %%
airports.head()
# Out:
#   airport            airportname                   city state        latitude  \
# 0    SBAA  CONCEIÇÃO DO ARAGUAIA  CONCEIÇÃO DO ARAGUAIA    PA   8° 20' 55'' S
# 1    SBAE          BAURU/AREALVA        BAURU E AREALVA    SP   22° 9' 28'' S
# 2    SBAM                  AMAPÁ                  AMAPÁ    AP    2° 4' 22'' N
# 3    SBAQ   BARTOLOMEU DE GUSMÃO             ARARAQUARA    SP  21° 48' 16'' S
# 4    SBAR            SANTA MARIA                ARACAJU    SE   10° 59' 7'' S
#
#         longitude altitude                                operation
# 0  49° 18' 11'' W    199 m          VFR Diurno/Noturno e IFR Diurno
# 1    49° 4' 6'' W    594 m  VFR Diurno/Noturno e IFR Diurno/Noturno
# 2  50° 51' 45'' W     14 m                  VFR Diurno e IFR Diurno
# 3   48° 8' 25'' W    711 m  VFR Diurno/Noturno e IFR Diurno/Noturno
# 4   37° 4' 24'' W      7 m  VFR Diurno/Noturno e IFR Diurno/Noturno

# %% [markdown]
# ### List of codes (two letters) used when there was a flight delay (departure)
# I have found two lists that define two-letter codes used by the aircraft crew to justify the delay of the flights: a short and a long one.
#
# Source: https://goo.gl/vUC8BX (last access: nov, 15th, 2017)

# %%
# ------------------------------------------------------------------
# List of codes (two letters) used to justify a delay on the flight
# - delayCodesShortlist.csv: list with YYY codes
# - delayCodesLongList.csv: list with XXX codes
# ------------------------------------------------------------------
delaycodes = pd.read_csv('data/delayCodesShortlist.csv', sep = ';')
delaycodesLongList = pd.read_csv('data/delayCodesLonglist.csv', sep = ';')

# %%
delaycodes.head()
# Out:
#   delaycode  delayOrigin   duetoweather   autorizationdelay  \
# 0        AA            B              0                   0
# 1        AF            A              0                   0
# 2        AG            A              0                   0
# 3        AI            A              0                   0
# 4        AJ            B              0                   0
#
#                                     delaydescription
# 0   ATRASO AEROPORTO DE ALTERNATIVA de ORDEM TÉCNICA
# 1     FACILIDADES DO AEROPORTO - RESTRIÇÕES DE APOIO
# 2                           MIGRAÇÃO/ALFÂNDEGA/SAÚDE
# 3                    AEROPORTO DE ORIGEM INTERDITADO
# 4                   AEROPORTO DE DESTINO INTERDITADO

# %% [markdown]
# ### Merging datasets and adjusting the data

# %%
# Transform columns with date/time from 'object' to date format
flights['departureest'] = pd.to_datetime(flights['departureest'],errors='ignore')
flights['departurereal'] = pd.to_datetime(flights['departurereal'],errors='ignore')
flights['arrivalest'] = pd.to_datetime(flights['arrivalest'],errors='ignore')
flights['arrivalreal'] = pd.to_datetime(flights['arrivalreal'],errors='ignore')

# %%
# Merge "flights" dataset with "airports" in order to identify 
#   local flights (origin and destination are in Brazil)
flights = pd.merge(flights, airports, left_on="airportA", right_on="airport", how='left')

# %%
flights = pd.merge(flights, airports, left_on="airportB", right_on="airport", how='left')

# %%
flights.head()
# Out:
#   airline  flightcode authcode linecode airportA airportB        departureest  \
# 0     AAL         213        0        I     KMIA     SBBR 2017-01-02 01:20:00
# 1     AAL         213        0        I     KMIA     SBBR 2017-01-24 01:20:00
# 2     AAL         213        0        I     KMIA     SBBR 2017-01-29 01:20:00
# 3     AAL         213        0        I     KMIA     SBBR 2017-01-23 01:20:00
# 4     AAL         213        0        I     KMIA     SBBR 2017-01-25 01:20:00
#
#         departurereal          arrivalest         arrivalreal  \
# 0 2017-01-02 01:20:00 2017-01-02 09:00:00 2017-01-02 09:00:00
# 1 2017-01-24 01:20:00 2017-01-24 09:00:00 2017-01-24 09:00:00
# 2 2017-01-29 01:20:00 2017-01-29 09:00:00 2017-01-29 09:00:00
# 3 2017-01-23 01:20:00 2017-01-23 09:00:00 2017-01-23 09:00:00
# 4 2017-01-25 01:20:00 2017-01-25 09:00:00 2017-01-25 09:00:00
#
#                     ...                    altitude_x operation_x airport_y  \
# 0                   ...                           NaN         NaN      SBBR
# 1                   ...                           NaN         NaN      SBBR
# 2                   ...                           NaN         NaN      SBBR
# 3                   ...                           NaN         NaN      SBBR
# 4                   ...                           NaN         NaN      SBBR
#
#                      airportname_y    city_y state_y      latitude_y  \
# 0  PRESIDENTE JUSCELINO KUBITSCHEK  BRASÍLIA      DF  15° 52' 16'' S
# 1  PRESIDENTE JUSCELINO KUBITSCHEK  BRASÍLIA      DF  15° 52' 16'' S
# 2  PRESIDENTE JUSCELINO KUBITSCHEK  BRASÍLIA      DF  15° 52' 16'' S
# 3  PRESIDENTE JUSCELINO KUBITSCHEK  BRASÍLIA      DF  15° 52' 16'' S
# 4  PRESIDENTE JUSCELINO KUBITSCHEK  BRASÍLIA      DF  15° 52' 16'' S
#
#      longitude_y altitude_y                              operation_y
# 0  47° 55' 7'' W     1066 m  VFR Diurno/Noturno e IFR Diurno/Noturno
# 1  47° 55' 7'' W     1066 m  VFR Diurno/Noturno e IFR Diurno/Noturno
# 2  47° 55' 7'' W     1066 m  VFR Diurno/Noturno e IFR Diurno/Noturno
# 3  47° 55' 7'' W     1066 m  VFR Diurno/Noturno e IFR Diurno/Noturno
# 4  47° 55' 7'' W     1066 m  VFR Diurno/Noturno e IFR Diurno/Noturno
#
# [5 rows x 28 columns]

# %% [markdown]
# # --- Sandbox. Test area: Danger! Do Not Trepass Beyond This Point! --

# %%
dfFlights = flights[['airportA']]

# %%
dfAirports = airports[['airport']]

# %%
dfFlights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 820958 entries, 0 to 820957
# Data columns (total 1 columns):
# airportA    820958 non-null object
# dtypes: object(1)
# memory usage: 6.3+ MB

# %%
dfAirports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 589 entries, 0 to 588
# Data columns (total 1 columns):
# airport    589 non-null object
# dtypes: object(1)
# memory usage: 4.7+ KB

# %%
display('dfFlights', 'dfAirports', pd.merge(dfFlights, dfAirports, left_on="airportA", right_on="airport"))
# Out:
# 'dfFlights'
# 'dfAirports'
#        airportA airport
# 0          SBBR    SBBR
# 1          SBBR    SBBR
# 2          SBBR    SBBR
# 3          SBBR    SBBR
# 4          SBBR    SBBR
# 5          SBBR    SBBR
# 6          SBBR    SBBR
# 7          SBBR    SBBR
# 8          SBBR    SBBR
# 9          SBBR    SBBR
# 10         SBBR    SBBR
# 11         SBBR    SBBR
# 12         SBBR    SBBR
# 13         SBBR    SBBR
# 14         SBBR    SBBR
# 15         SBBR    SBBR
# 16         SBBR    SBBR
# 17         SBBR    SBBR
# 18         SBBR    SBBR
# 19         SBBR    SBBR
# 20         SBBR    SBBR
# 21         SBBR    SBBR
# 22         SBBR    SBBR
# 23         SBBR    SBBR
# 24         SBBR    SBBR
# 25         SBBR    SBBR
# 26         SBBR    SBBR
# 27         SBBR    SBBR
# 28         SBBR    SBBR
# 29         SBBR    SBBR
# ...         ...     ...
# 722950     SBNM    SBNM
# 722951     SBNM    SBNM
# 722952     SBNM    SBNM
# 722953     SBNM    SBNM
# 722954     SBNM    SBNM
# 722955     SBNM    SBNM
# 722956     SBNM    SBNM
# 722957     SBNM    SBNM
# 722958     SBNM    SBNM
# 722959     SBNM    SBNM
# 722960     SBNM    SBNM
# 722961     SBNM    SBNM
# 722962     SBNM    SBNM
# 722963     SBNM    SBNM
# 722964     SBNM    SBNM
# 722965     SBNM    SBNM
# 722966     SBNM    SBNM
# 722967     SBNM    SBNM
# 722968     SBNM    SBNM
# 722969     SBNM    SBNM
# 722970     SBNM    SBNM
# 722971     SBNM    SBNM
# 722972     SBNM    SBNM
# 722973     SBNM    SBNM
# 722974     SBNM    SBNM
# 722975     SBNM    SBNM
# 722976     SBNM    SBNM
# 722977     SBNM    SBNM
# 722978     SBNM    SBNM
# 722979     SBJD    SBJD
#
# [722980 rows x 2 columns]

# %%
# Not working: 
# pd.merge('dfFlights', 'dfAirports', pd.merge(dfFlights, dfAirports, left_on='airportA', right_on='airport'))
# ------------------------

# %%
# A more easy attempt
df1 = pd.DataFrame({'airportA': ['SBBH', 'SBCG', 'SBKP', 'KMIA', 'HONO'],
                    'airportB': ['SBBR', 'SBCT', 'SBAM', 'GERM', 'ENGL']},
                   columns=['airportA', 'airportB'])
df2 = pd.DataFrame({'airport': ['SBBH', 'SBCG', 'SBKP', 'SBBR', 'SBCT', 'SBAM'],
                    'state': ['MG', 'SP', 'SP', 'DF', 'PR', 'AM']},
                   columns=['airport', 'state'])

# %%
df1
# Out:
#   airportA airportB
# 0     SBBH     SBBR
# 1     SBCG     SBCT
# 2     SBKP     SBAM
# 3     KMIA     GERM
# 4     HONO     ENGL

# %%
df2
# Out:
#   airport state
# 0    SBBH    MG
# 1    SBCG    SP
# 2    SBKP    SP
# 3    SBBR    DF
# 4    SBCT    PR
# 5    SBAM    AM

# %%
display('df1', 'df2', pd.merge(df1, df2, left_on="airportA", right_on="airport", how='left'))
# Out:
# 'df1'
# 'df2'
#   airportA airportB airport state
# 0     SBBH     SBBR    SBBH    MG
# 1     SBCG     SBCT    SBCG    SP
# 2     SBKP     SBAM    SBKP    SP
# 3     KMIA     GERM     NaN   NaN
# 4     HONO     ENGL     NaN   NaN

# %%
df3 = pd.merge(df1, df2, left_on="airportA", right_on="airport", how='left')

# %%
df3
# Out:
#   airportA airportB airport state
# 0     SBBH     SBBR    SBBH    MG
# 1     SBCG     SBCT    SBCG    SP
# 2     SBKP     SBAM    SBKP    SP
# 3     KMIA     GERM     NaN   NaN
# 4     HONO     ENGL     NaN   NaN

# %%
display('df3', 'df2', pd.merge(df3, df2, left_on="airportB", right_on="airport", how='left'))
# Out:
# 'df3'
# 'df2'
#   airportA airportB airport_x state_x airport_y state_y
# 0     SBBH     SBBR      SBBH      MG      SBBR      DF
# 1     SBCG     SBCT      SBCG      SP      SBCT      PR
# 2     SBKP     SBAM      SBKP      SP      SBAM      AM
# 3     KMIA     GERM       NaN     NaN       NaN     NaN
# 4     HONO     ENGL       NaN     NaN       NaN     NaN

# %% [markdown]
# ### More tests...

# %%
sampleFlights = pd.read_csv('data/sampleFlights.csv', sep = ';', parse_dates = True)
sampleAirports = pd.read_csv('data/sampleAirports.csv', sep = ';', parse_dates = True)

# %%
sampleFlights.head()
# Out:
#   airline  flightcode  authcode linecode airportA airportB  \
# 0     AAL         213         0        I     KMIA     SBBR
# 1     AAL         214         0        I     SBBR     KMIA
# 2     AAL         215         0        I     KLAX     SBGR
# 3     AAL         216         0        I     SBGR     KLAX
# 4     AAL         900         0        I     SAEZ     KMIA
#
#           departureest        departurereal           arrivalest  \
# 0  2017-01-30 01:20:00  2017-01-30 01:20:00  2017-01-30 09:00:00
# 1  2017-01-05 23:55:00  2017-01-05 23:55:00  2017-01-06 07:45:00
# 2  2017-01-21 21:55:00  2017-01-21 21:55:00  2017-01-22 10:00:00
# 3  2017-01-15 00:05:00  2017-01-15 00:05:00  2017-01-15 12:35:00
# 4  2017-01-03 22:00:00  2017-01-03 22:00:00  2017-01-04 07:17:00
#
#            arrivalreal flightstatus problemcode
# 0  2017-01-30 09:00:00    REALIZADO         NaN
# 1  2017-01-06 07:45:00    REALIZADO         NaN
# 2  2017-01-22 10:00:00    REALIZADO         NaN
# 3  2017-01-15 12:35:00    REALIZADO         NaN
# 4  2017-01-04 07:17:00    REALIZADO         NaN

# %%
sampleAirports.head()
# Out:
#   airport                                        airportname            city  \
# 0    SBBR                    PRESIDENTE JUSCELINO KUBITSCHEK        BRASÍLIA
# 1    SBGR        GUARULHOS - GOVERNADOR ANDRÉ FRANCO MONTORO       GUARULHOS
# 2    SBGL  AEROPORTO INTERNACIONAL DO RIO DE JANEIRO/GALE...  RIO DE JANEIRO
# 3    SBSP                                          CONGONHAS       SÃO PAULO
# 4    SBRJ                                      SANTOS DUMONT  RIO DE JANEIRO
#
#   state        latitude       longitude altitude  \
# 0    DF  15° 52' 16'' S   47° 55' 7'' W   1066 m
# 1    SP   23° 26' 8'' S  46° 28' 23'' W    750 m
# 2    RJ  22° 48' 36'' S   43° 15' 2'' W      9 m
# 3    SP  23° 37' 34'' S  46° 39' 23'' W    802 m
# 4    RJ  22° 54' 36'' S   43° 9' 45'' W      3 m
#
#                                  operation
# 0  VFR Diurno/Noturno e IFR Diurno/Noturno
# 1  VFR Diurno/Noturno e IFR Diurno/Noturno
# 2  VFR Diurno/Noturno e IFR Diurno/Noturno
# 3  VFR Diurno/Noturno e IFR Diurno/Noturno
# 4  VFR Diurno/Noturno e IFR Diurno/Noturno

# %%
display('sampleFlights', 'sampleAirports', 
        pd.merge(sampleFlights, sampleAirports, left_on="airportA", right_on="airport", how='left'))
# Out:
# 'sampleFlights'
# 'sampleAirports'
#    airline  flightcode  authcode linecode airportA airportB  \
# 0      AAL         213         0        I     KMIA     SBBR
# 1      AAL         214         0        I     SBBR     KMIA
# 2      AAL         215         0        I     KLAX     SBGR
# 3      AAL         216         0        I     SBGR     KLAX
# 4      AAL         900         0        I     SAEZ     KMIA
# 5      AAL         904         0        I     SBGL     KMIA
# 6      AAL         953         0        I     KJFK     SAEZ
# 7      AAL         984         0        I     SUMU     KMIA
# 8      ACA          90         0        I     CYYZ     SBGR
# 9      ONE        6176         0        N     SBSP     SBBR
# 10     AZU        2409         0        R     SBRJ     SBVT
# 11     AZU        2410         0        N     SBGR     SBCF
# 12     AZU        2415         0        N     SBCF     SBGR
# 13     AZU        2407         0        N     SBKP     SBCT
# 14     AZU        9212         2        N     SBKP     SBLO
# 15     AZU        9213         2        N     SBLO     SBKP
# 16     GLO        7612         2        I     SBGL     SACO
# 17     GLO        7617         0        I     SAAR     SBGL
# 18     TAM        3004         0        E     SBCT     SBSP
#
#            departureest        departurereal           arrivalest  \
# 0   2017-01-30 01:20:00  2017-01-30 01:20:00  2017-01-30 09:00:00
# 1   2017-01-05 23:55:00  2017-01-05 23:55:00  2017-01-06 07:45:00
# 2   2017-01-21 21:55:00  2017-01-21 21:55:00  2017-01-22 10:00:00
# 3   2017-01-15 00:05:00  2017-01-15 00:05:00  2017-01-15 12:35:00
# 4   2017-01-03 22:00:00  2017-01-03 22:00:00  2017-01-04 07:17:00
# 5   2017-01-03 22:40:00  2017-01-03 22:40:00  2017-01-04 07:35:00
# 6   2017-01-21 00:59:00  2017-01-21 00:59:00  2017-01-21 11:41:00
# 7   2017-01-11 22:40:00  2017-01-11 22:40:00  2017-01-12 08:07:00
# 8   2017-01-19 01:55:00  2017-01-19 01:55:00  2017-01-19 11:55:00
# 9   2017-04-09 15:40:00  2017-04-09 15:32:00  2017-04-09 17:30:00
# 10  2017-05-30 11:30:00  2017-05-30 11:30:00  2017-05-30 12:35:00
# 11  2017-05-20 06:00:00  2017-05-20 05:52:00  2017-05-20 07:20:00
# 12  2017-05-08 17:50:00  2017-05-08 17:48:00  2017-05-08 19:15:00
# 13  2017-06-21 19:50:00                  NaN  2017-06-21 20:50:00
# 14                  NaN  2017-06-10 09:30:00                  NaN
# 15                  NaN  2017-06-07 12:13:00                  NaN
# 16                  NaN  2017-06-05 22:32:00                  NaN
# 17  2017-06-05 03:10:00  2017-06-05 03:10:00  2017-06-05 05:55:00
# 18  2017-06-01 08:23:00  2017-06-01 08:10:00  2017-06-01 09:20:00
#
#             arrivalreal flightstatus problemcode airport  \
# 0   2017-01-30 09:00:00    REALIZADO         NaN     NaN
# 1   2017-01-06 07:45:00    REALIZADO         NaN    SBBR
# 2   2017-01-22 10:00:00    REALIZADO         NaN     NaN
# 3   2017-01-15 12:35:00    REALIZADO         NaN    SBGR
# 4   2017-01-04 07:17:00    REALIZADO         NaN     NaN
# 5   2017-01-04 07:35:00    REALIZADO         NaN    SBGL
# 6   2017-01-21 11:41:00    REALIZADO         NaN     NaN
# 7   2017-01-12 08:07:00    REALIZADO         NaN     NaN
# 8   2017-01-19 11:32:00    REALIZADO          MX     NaN
# 9   2017-04-09 17:03:00    REALIZADO         NaN    SBSP
# 10  2017-05-30 12:35:00    REALIZADO         NaN    SBRJ
# 11  2017-05-20 06:50:00    REALIZADO          HD    SBGR
# 12  2017-05-08 19:04:00    REALIZADO          HD    SBCF
# 13                  NaN    CANCELADO          XB    SBKP
# 14  2017-06-10 11:06:00    REALIZADO         NaN    SBKP
# 15  2017-06-07 13:36:00    REALIZADO         NaN    SBLO
# 16  2017-06-06 02:37:00    REALIZADO         NaN    SBGL
# 17  2017-06-05 05:55:00    REALIZADO         NaN     NaN
# 18  2017-06-01 09:05:00    REALIZADO          AT    SBCT
#
#                                           airportname            city state  \
# 0                                                 NaN             NaN   NaN
# 1                     PRESIDENTE JUSCELINO KUBITSCHEK        BRASÍLIA    DF
# 2                                                 NaN             NaN   NaN
# 3         GUARULHOS - GOVERNADOR ANDRÉ FRANCO MONTORO       GUARULHOS    SP
# 4                                                 NaN             NaN   NaN
# 5   AEROPORTO INTERNACIONAL DO RIO DE JANEIRO/GALE...  RIO DE JANEIRO    RJ
# 6                                                 NaN             NaN   NaN
# 7                                                 NaN             NaN   NaN
# 8                                                 NaN             NaN   NaN
# 9                                           CONGONHAS       SÃO PAULO    SP
# 10                                      SANTOS DUMONT  RIO DE JANEIRO    RJ
# 11        GUARULHOS - GOVERNADOR ANDRÉ FRANCO MONTORO       GUARULHOS    SP
# 12                                     TANCREDO NEVES         CONFINS    MG
# 13                                          VIRACOPOS        CAMPINAS    SP
# 14                                          VIRACOPOS        CAMPINAS    SP
# 15                              GOVERNADOR JOSÉ RICHA        LONDRINA    PR
# 16  AEROPORTO INTERNACIONAL DO RIO DE JANEIRO/GALE...  RIO DE JANEIRO    RJ
# 17                                                NaN             NaN   NaN
# 18                                        AFONSO PENA        CURITIBA    PR
#
#           latitude       longitude altitude  \
# 0              NaN             NaN      NaN
# 1   15° 52' 16'' S   47° 55' 7'' W   1066 m
# 2              NaN             NaN      NaN
# 3    23° 26' 8'' S  46° 28' 23'' W    750 m
# 4              NaN             NaN      NaN
# 5   22° 48' 36'' S   43° 15' 2'' W      9 m
# 6              NaN             NaN      NaN
# 7              NaN             NaN      NaN
# 8              NaN             NaN      NaN
# 9   23° 37' 34'' S  46° 39' 23'' W    802 m
# 10  22° 54' 36'' S   43° 9' 45'' W      3 m
# 11   23° 26' 8'' S  46° 28' 23'' W    750 m
# 12  19° 37' 26'' S  43° 58' 17'' W    827 m
# 13   23° 0' 25'' S    47° 8' 4'' W    661 m
# 14   23° 0' 25'' S    47° 8' 4'' W    661 m
# 15  23° 19' 49'' S   51° 8' 12'' W    569 m
# 16  22° 48' 36'' S   43° 15' 2'' W      9 m
# 17             NaN             NaN      NaN
# 18  25° 31' 54'' S  49° 10' 34'' W    911 m
#
#                                   operation
# 0                                       NaN
# 1   VFR Diurno/Noturno e IFR Diurno/Noturno
# 2                                       NaN
# 3   VFR Diurno/Noturno e IFR Diurno/Noturno
# 4                                       NaN
# 5   VFR Diurno/Noturno e IFR Diurno/Noturno
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9   VFR Diurno/Noturno e IFR Diurno/Noturno
# 10  VFR Diurno/Noturno e IFR Diurno/Noturno
# 11  VFR Diurno/Noturno e IFR Diurno/Noturno
# 12  VFR Diurno/Noturno e IFR Diurno/Noturno
# 13  VFR Diurno/Noturno e IFR Diurno/Noturno
# 14  VFR Diurno/Noturno e IFR Diurno/Noturno
# 15  VFR Diurno/Noturno e IFR Diurno/Noturno
# 16  VFR Diurno/Noturno e IFR Diurno/Noturno
# 17                                      NaN
# 18  VFR Diurno/Noturno e IFR Diurno/Noturno

# %%
sampleMergeTemp = pd.merge(sampleFlights, sampleAirports, left_on="airportA", right_on="airport", how='left')

# %%
sampleMergeTemp
# Out:
#    airline  flightcode  authcode linecode airportA airportB  \
# 0      AAL         213         0        I     KMIA     SBBR
# 1      AAL         214         0        I     SBBR     KMIA
# 2      AAL         215         0        I     KLAX     SBGR
# 3      AAL         216         0        I     SBGR     KLAX
# 4      AAL         900         0        I     SAEZ     KMIA
# 5      AAL         904         0        I     SBGL     KMIA
# 6      AAL         953         0        I     KJFK     SAEZ
# 7      AAL         984         0        I     SUMU     KMIA
# 8      ACA          90         0        I     CYYZ     SBGR
# 9      ONE        6176         0        N     SBSP     SBBR
# 10     AZU        2409         0        R     SBRJ     SBVT
# 11     AZU        2410         0        N     SBGR     SBCF
# 12     AZU        2415         0        N     SBCF     SBGR
# 13     AZU        2407         0        N     SBKP     SBCT
# 14     AZU        9212         2        N     SBKP     SBLO
# 15     AZU        9213         2        N     SBLO     SBKP
# 16     GLO        7612         2        I     SBGL     SACO
# 17     GLO        7617         0        I     SAAR     SBGL
# 18     TAM        3004         0        E     SBCT     SBSP
#
#            departureest        departurereal           arrivalest  \
# 0   2017-01-30 01:20:00  2017-01-30 01:20:00  2017-01-30 09:00:00
# 1   2017-01-05 23:55:00  2017-01-05 23:55:00  2017-01-06 07:45:00
# 2   2017-01-21 21:55:00  2017-01-21 21:55:00  2017-01-22 10:00:00
# 3   2017-01-15 00:05:00  2017-01-15 00:05:00  2017-01-15 12:35:00
# 4   2017-01-03 22:00:00  2017-01-03 22:00:00  2017-01-04 07:17:00
# 5   2017-01-03 22:40:00  2017-01-03 22:40:00  2017-01-04 07:35:00
# 6   2017-01-21 00:59:00  2017-01-21 00:59:00  2017-01-21 11:41:00
# 7   2017-01-11 22:40:00  2017-01-11 22:40:00  2017-01-12 08:07:00
# 8   2017-01-19 01:55:00  2017-01-19 01:55:00  2017-01-19 11:55:00
# 9   2017-04-09 15:40:00  2017-04-09 15:32:00  2017-04-09 17:30:00
# 10  2017-05-30 11:30:00  2017-05-30 11:30:00  2017-05-30 12:35:00
# 11  2017-05-20 06:00:00  2017-05-20 05:52:00  2017-05-20 07:20:00
# 12  2017-05-08 17:50:00  2017-05-08 17:48:00  2017-05-08 19:15:00
# 13  2017-06-21 19:50:00                  NaN  2017-06-21 20:50:00
# 14                  NaN  2017-06-10 09:30:00                  NaN
# 15                  NaN  2017-06-07 12:13:00                  NaN
# 16                  NaN  2017-06-05 22:32:00                  NaN
# 17  2017-06-05 03:10:00  2017-06-05 03:10:00  2017-06-05 05:55:00
# 18  2017-06-01 08:23:00  2017-06-01 08:10:00  2017-06-01 09:20:00
#
#             arrivalreal flightstatus problemcode airport  \
# 0   2017-01-30 09:00:00    REALIZADO         NaN     NaN
# 1   2017-01-06 07:45:00    REALIZADO         NaN    SBBR
# 2   2017-01-22 10:00:00    REALIZADO         NaN     NaN
# 3   2017-01-15 12:35:00    REALIZADO         NaN    SBGR
# 4   2017-01-04 07:17:00    REALIZADO         NaN     NaN
# 5   2017-01-04 07:35:00    REALIZADO         NaN    SBGL
# 6   2017-01-21 11:41:00    REALIZADO         NaN     NaN
# 7   2017-01-12 08:07:00    REALIZADO         NaN     NaN
# 8   2017-01-19 11:32:00    REALIZADO          MX     NaN
# 9   2017-04-09 17:03:00    REALIZADO         NaN    SBSP
# 10  2017-05-30 12:35:00    REALIZADO         NaN    SBRJ
# 11  2017-05-20 06:50:00    REALIZADO          HD    SBGR
# 12  2017-05-08 19:04:00    REALIZADO          HD    SBCF
# 13                  NaN    CANCELADO          XB    SBKP
# 14  2017-06-10 11:06:00    REALIZADO         NaN    SBKP
# 15  2017-06-07 13:36:00    REALIZADO         NaN    SBLO
# 16  2017-06-06 02:37:00    REALIZADO         NaN    SBGL
# 17  2017-06-05 05:55:00    REALIZADO         NaN     NaN
# 18  2017-06-01 09:05:00    REALIZADO          AT    SBCT
#
#                                           airportname            city state  \
# 0                                                 NaN             NaN   NaN
# 1                     PRESIDENTE JUSCELINO KUBITSCHEK        BRASÍLIA    DF
# 2                                                 NaN             NaN   NaN
# 3         GUARULHOS - GOVERNADOR ANDRÉ FRANCO MONTORO       GUARULHOS    SP
# 4                                                 NaN             NaN   NaN
# 5   AEROPORTO INTERNACIONAL DO RIO DE JANEIRO/GALE...  RIO DE JANEIRO    RJ
# 6                                                 NaN             NaN   NaN
# 7                                                 NaN             NaN   NaN
# 8                                                 NaN             NaN   NaN
# 9                                           CONGONHAS       SÃO PAULO    SP
# 10                                      SANTOS DUMONT  RIO DE JANEIRO    RJ
# 11        GUARULHOS - GOVERNADOR ANDRÉ FRANCO MONTORO       GUARULHOS    SP
# 12                                     TANCREDO NEVES         CONFINS    MG
# 13                                          VIRACOPOS        CAMPINAS    SP
# 14                                          VIRACOPOS        CAMPINAS    SP
# 15                              GOVERNADOR JOSÉ RICHA        LONDRINA    PR
# 16  AEROPORTO INTERNACIONAL DO RIO DE JANEIRO/GALE...  RIO DE JANEIRO    RJ
# 17                                                NaN             NaN   NaN
# 18                                        AFONSO PENA        CURITIBA    PR
#
#           latitude       longitude altitude  \
# 0              NaN             NaN      NaN
# 1   15° 52' 16'' S   47° 55' 7'' W   1066 m
# 2              NaN             NaN      NaN
# 3    23° 26' 8'' S  46° 28' 23'' W    750 m
# 4              NaN             NaN      NaN
# 5   22° 48' 36'' S   43° 15' 2'' W      9 m
# 6              NaN             NaN      NaN
# 7              NaN             NaN      NaN
# 8              NaN             NaN      NaN
# 9   23° 37' 34'' S  46° 39' 23'' W    802 m
# 10  22° 54' 36'' S   43° 9' 45'' W      3 m
# 11   23° 26' 8'' S  46° 28' 23'' W    750 m
# 12  19° 37' 26'' S  43° 58' 17'' W    827 m
# 13   23° 0' 25'' S    47° 8' 4'' W    661 m
# 14   23° 0' 25'' S    47° 8' 4'' W    661 m
# 15  23° 19' 49'' S   51° 8' 12'' W    569 m
# 16  22° 48' 36'' S   43° 15' 2'' W      9 m
# 17             NaN             NaN      NaN
# 18  25° 31' 54'' S  49° 10' 34'' W    911 m
#
#                                   operation
# 0                                       NaN
# 1   VFR Diurno/Noturno e IFR Diurno/Noturno
# 2                                       NaN
# 3   VFR Diurno/Noturno e IFR Diurno/Noturno
# 4                                       NaN
# 5   VFR Diurno/Noturno e IFR Diurno/Noturno
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9   VFR Diurno/Noturno e IFR Diurno/Noturno
# 10  VFR Diurno/Noturno e IFR Diurno/Noturno
# 11  VFR Diurno/Noturno e IFR Diurno/Noturno
# 12  VFR Diurno/Noturno e IFR Diurno/Noturno
# 13  VFR Diurno/Noturno e IFR Diurno/Noturno
# 14  VFR Diurno/Noturno e IFR Diurno/Noturno
# 15  VFR Diurno/Noturno e IFR Diurno/Noturno
# 16  VFR Diurno/Noturno e IFR Diurno/Noturno
# 17                                      NaN
# 18  VFR Diurno/Noturno e IFR Diurno/Noturno

# %%
display('sampleMergeTemp', 'sampleAirports', 
        pd.merge(sampleMergeTemp, sampleAirports, left_on="airportB", right_on="airport", how='left'))
# Out:
# 'sampleMergeTemp'
# 'sampleAirports'
#    airline  flightcode  authcode linecode airportA airportB  \
# 0      AAL         213         0        I     KMIA     SBBR
# 1      AAL         214         0        I     SBBR     KMIA
# 2      AAL         215         0        I     KLAX     SBGR
# 3      AAL         216         0        I     SBGR     KLAX
# 4      AAL         900         0        I     SAEZ     KMIA
# 5      AAL         904         0        I     SBGL     KMIA
# 6      AAL         953         0        I     KJFK     SAEZ
# 7      AAL         984         0        I     SUMU     KMIA
# 8      ACA          90         0        I     CYYZ     SBGR
# 9      ONE        6176         0        N     SBSP     SBBR
# 10     AZU        2409         0        R     SBRJ     SBVT
# 11     AZU        2410         0        N     SBGR     SBCF
# 12     AZU        2415         0        N     SBCF     SBGR
# 13     AZU        2407         0        N     SBKP     SBCT
# 14     AZU        9212         2        N     SBKP     SBLO
# 15     AZU        9213         2        N     SBLO     SBKP
# 16     GLO        7612         2        I     SBGL     SACO
# 17     GLO        7617         0        I     SAAR     SBGL
# 18     TAM        3004         0        E     SBCT     SBSP
#
#            departureest        departurereal           arrivalest  \
# 0   2017-01-30 01:20:00  2017-01-30 01:20:00  2017-01-30 09:00:00
# 1   2017-01-05 23:55:00  2017-01-05 23:55:00  2017-01-06 07:45:00
# 2   2017-01-21 21:55:00  2017-01-21 21:55:00  2017-01-22 10:00:00
# 3   2017-01-15 00:05:00  2017-01-15 00:05:00  2017-01-15 12:35:00
# 4   2017-01-03 22:00:00  2017-01-03 22:00:00  2017-01-04 07:17:00
# 5   2017-01-03 22:40:00  2017-01-03 22:40:00  2017-01-04 07:35:00
# 6   2017-01-21 00:59:00  2017-01-21 00:59:00  2017-01-21 11:41:00
# 7   2017-01-11 22:40:00  2017-01-11 22:40:00  2017-01-12 08:07:00
# 8   2017-01-19 01:55:00  2017-01-19 01:55:00  2017-01-19 11:55:00
# 9   2017-04-09 15:40:00  2017-04-09 15:32:00  2017-04-09 17:30:00
# 10  2017-05-30 11:30:00  2017-05-30 11:30:00  2017-05-30 12:35:00
# 11  2017-05-20 06:00:00  2017-05-20 05:52:00  2017-05-20 07:20:00
# 12  2017-05-08 17:50:00  2017-05-08 17:48:00  2017-05-08 19:15:00
# 13  2017-06-21 19:50:00                  NaN  2017-06-21 20:50:00
# 14                  NaN  2017-06-10 09:30:00                  NaN
# 15                  NaN  2017-06-07 12:13:00                  NaN
# 16                  NaN  2017-06-05 22:32:00                  NaN
# 17  2017-06-05 03:10:00  2017-06-05 03:10:00  2017-06-05 05:55:00
# 18  2017-06-01 08:23:00  2017-06-01 08:10:00  2017-06-01 09:20:00
#
#             arrivalreal                   ...                    altitude_x  \
# 0   2017-01-30 09:00:00                   ...                           NaN
# 1   2017-01-06 07:45:00                   ...                        1066 m
# 2   2017-01-22 10:00:00                   ...                           NaN
# 3   2017-01-15 12:35:00                   ...                         750 m
# 4   2017-01-04 07:17:00                   ...                           NaN
# 5   2017-01-04 07:35:00                   ...                           9 m
# 6   2017-01-21 11:41:00                   ...                           NaN
# 7   2017-01-12 08:07:00                   ...                           NaN
# 8   2017-01-19 11:32:00                   ...                           NaN
# 9   2017-04-09 17:03:00                   ...                         802 m
# 10  2017-05-30 12:35:00                   ...                           3 m
# 11  2017-05-20 06:50:00                   ...                         750 m
# 12  2017-05-08 19:04:00                   ...                         827 m
# 13                  NaN                   ...                         661 m
# 14  2017-06-10 11:06:00                   ...                         661 m
# 15  2017-06-07 13:36:00                   ...                         569 m
# 16  2017-06-06 02:37:00                   ...                           9 m
# 17  2017-06-05 05:55:00                   ...                           NaN
# 18  2017-06-01 09:05:00                   ...                         911 m
#
#                                 operation_x airport_y  \
# 0                                       NaN      SBBR
# 1   VFR Diurno/Noturno e IFR Diurno/Noturno       NaN
# 2                                       NaN      SBGR
# 3   VFR Diurno/Noturno e IFR Diurno/Noturno       NaN
# 4                                       NaN       NaN
# 5   VFR Diurno/Noturno e IFR Diurno/Noturno       NaN
# 6                                       NaN       NaN
# 7                                       NaN       NaN
# 8                                       NaN      SBGR
# 9   VFR Diurno/Noturno e IFR Diurno/Noturno      SBBR
# 10  VFR Diurno/Noturno e IFR Diurno/Noturno       NaN
# 11  VFR Diurno/Noturno e IFR Diurno/Noturno      SBCF
# 12  VFR Diurno/Noturno e IFR Diurno/Noturno      SBGR
# 13  VFR Diurno/Noturno e IFR Diurno/Noturno      SBCT
# 14  VFR Diurno/Noturno e IFR Diurno/Noturno      SBLO
# 15  VFR Diurno/Noturno e IFR Diurno/Noturno      SBKP
# 16  VFR Diurno/Noturno e IFR Diurno/Noturno       NaN
# 17                                      NaN      SBGL
# 18  VFR Diurno/Noturno e IFR Diurno/Noturno      SBSP
#
#                                         airportname_y          city_y state_y  \
# 0                     PRESIDENTE JUSCELINO KUBITSCHEK        BRASÍLIA      DF
# 1                                                 NaN             NaN     NaN
# 2         GUARULHOS - GOVERNADOR ANDRÉ FRANCO MONTORO       GUARULHOS      SP
# 3                                                 NaN             NaN     NaN
# 4                                                 NaN             NaN     NaN
# 5                                                 NaN             NaN     NaN
# 6                                                 NaN             NaN     NaN
# 7                                                 NaN             NaN     NaN
# 8         GUARULHOS - GOVERNADOR ANDRÉ FRANCO MONTORO       GUARULHOS      SP
# 9                     PRESIDENTE JUSCELINO KUBITSCHEK        BRASÍLIA      DF
# 10                                                NaN             NaN     NaN
# 11                                     TANCREDO NEVES         CONFINS      MG
# 12        GUARULHOS - GOVERNADOR ANDRÉ FRANCO MONTORO       GUARULHOS      SP
# 13                                        AFONSO PENA        CURITIBA      PR
# 14                              GOVERNADOR JOSÉ RICHA        LONDRINA      PR
# 15                                          VIRACOPOS        CAMPINAS      SP
# 16                                                NaN             NaN     NaN
# 17  AEROPORTO INTERNACIONAL DO RIO DE JANEIRO/GALE...  RIO DE JANEIRO      RJ
# 18                                          CONGONHAS       SÃO PAULO      SP
#
#         latitude_y     longitude_y altitude_y  \
# 0   15° 52' 16'' S   47° 55' 7'' W     1066 m
# 1              NaN             NaN        NaN
# 2    23° 26' 8'' S  46° 28' 23'' W      750 m
# 3              NaN             NaN        NaN
# 4              NaN             NaN        NaN
# 5              NaN             NaN        NaN
# 6              NaN             NaN        NaN
# 7              NaN             NaN        NaN
# 8    23° 26' 8'' S  46° 28' 23'' W      750 m
# 9   15° 52' 16'' S   47° 55' 7'' W     1066 m
# 10             NaN             NaN        NaN
# 11  19° 37' 26'' S  43° 58' 17'' W      827 m
# 12   23° 26' 8'' S  46° 28' 23'' W      750 m
# 13  25° 31' 54'' S  49° 10' 34'' W      911 m
# 14  23° 19' 49'' S   51° 8' 12'' W      569 m
# 15   23° 0' 25'' S    47° 8' 4'' W      661 m
# 16             NaN             NaN        NaN
# 17  22° 48' 36'' S   43° 15' 2'' W        9 m
# 18  23° 37' 34'' S  46° 39' 23'' W      802 m
#
#                                 operation_y
# 0   VFR Diurno/Noturno e IFR Diurno/Noturno
# 1                                       NaN
# 2   VFR Diurno/Noturno e IFR Diurno/Noturno
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8   VFR Diurno/Noturno e IFR Diurno/Noturno
# 9   VFR Diurno/Noturno e IFR Diurno/Noturno
# 10                                      NaN
# 11  VFR Diurno/Noturno e IFR Diurno/Noturno
# 12  VFR Diurno/Noturno e IFR Diurno/Noturno
# 13  VFR Diurno/Noturno e IFR Diurno/Noturno
# 14  VFR Diurno/Noturno e IFR Diurno/Noturno
# 15  VFR Diurno/Noturno e IFR Diurno/Noturno
# 16                                      NaN
# 17  VFR Diurno/Noturno e IFR Diurno/Noturno
# 18  VFR Diurno/Noturno e IFR Diurno/Noturno
#
# [19 rows x 28 columns]

# %%
sampleMergeFinal = pd.merge(sampleMergeTemp, sampleAirports, left_on="airportB", right_on="airport", how='left')

# %%
sampleMergeFinal
# Out:
#    airline  flightcode  authcode linecode airportA airportB  \
# 0      AAL         213         0        I     KMIA     SBBR
# 1      AAL         214         0        I     SBBR     KMIA
# 2      AAL         215         0        I     KLAX     SBGR
# 3      AAL         216         0        I     SBGR     KLAX
# 4      AAL         900         0        I     SAEZ     KMIA
# 5      AAL         904         0        I     SBGL     KMIA
# 6      AAL         953         0        I     KJFK     SAEZ
# 7      AAL         984         0        I     SUMU     KMIA
# 8      ACA          90         0        I     CYYZ     SBGR
# 9      ONE        6176         0        N     SBSP     SBBR
# 10     AZU        2409         0        R     SBRJ     SBVT
# 11     AZU        2410         0        N     SBGR     SBCF
# 12     AZU        2415         0        N     SBCF     SBGR
# 13     AZU        2407         0        N     SBKP     SBCT
# 14     AZU        9212         2        N     SBKP     SBLO
# 15     AZU        9213         2        N     SBLO     SBKP
# 16     GLO        7612         2        I     SBGL     SACO
# 17     GLO        7617         0        I     SAAR     SBGL
# 18     TAM        3004         0        E     SBCT     SBSP
#
#            departureest        departurereal           arrivalest  \
# 0   2017-01-30 01:20:00  2017-01-30 01:20:00  2017-01-30 09:00:00
# 1   2017-01-05 23:55:00  2017-01-05 23:55:00  2017-01-06 07:45:00
# 2   2017-01-21 21:55:00  2017-01-21 21:55:00  2017-01-22 10:00:00
# 3   2017-01-15 00:05:00  2017-01-15 00:05:00  2017-01-15 12:35:00
# 4   2017-01-03 22:00:00  2017-01-03 22:00:00  2017-01-04 07:17:00
# 5   2017-01-03 22:40:00  2017-01-03 22:40:00  2017-01-04 07:35:00
# 6   2017-01-21 00:59:00  2017-01-21 00:59:00  2017-01-21 11:41:00
# 7   2017-01-11 22:40:00  2017-01-11 22:40:00  2017-01-12 08:07:00
# 8   2017-01-19 01:55:00  2017-01-19 01:55:00  2017-01-19 11:55:00
# 9   2017-04-09 15:40:00  2017-04-09 15:32:00  2017-04-09 17:30:00
# 10  2017-05-30 11:30:00  2017-05-30 11:30:00  2017-05-30 12:35:00
# 11  2017-05-20 06:00:00  2017-05-20 05:52:00  2017-05-20 07:20:00
# 12  2017-05-08 17:50:00  2017-05-08 17:48:00  2017-05-08 19:15:00
# 13  2017-06-21 19:50:00                  NaN  2017-06-21 20:50:00
# 14                  NaN  2017-06-10 09:30:00                  NaN
# 15                  NaN  2017-06-07 12:13:00                  NaN
# 16                  NaN  2017-06-05 22:32:00                  NaN
# 17  2017-06-05 03:10:00  2017-06-05 03:10:00  2017-06-05 05:55:00
# 18  2017-06-01 08:23:00  2017-06-01 08:10:00  2017-06-01 09:20:00
#
#             arrivalreal                   ...                    altitude_x  \
# 0   2017-01-30 09:00:00                   ...                           NaN
# 1   2017-01-06 07:45:00                   ...                        1066 m
# 2   2017-01-22 10:00:00                   ...                           NaN
# 3   2017-01-15 12:35:00                   ...                         750 m
# 4   2017-01-04 07:17:00                   ...                           NaN
# 5   2017-01-04 07:35:00                   ...                           9 m
# 6   2017-01-21 11:41:00                   ...                           NaN
# 7   2017-01-12 08:07:00                   ...                           NaN
# 8   2017-01-19 11:32:00                   ...                           NaN
# 9   2017-04-09 17:03:00                   ...                         802 m
# 10  2017-05-30 12:35:00                   ...                           3 m
# 11  2017-05-20 06:50:00                   ...                         750 m
# 12  2017-05-08 19:04:00                   ...                         827 m
# 13                  NaN                   ...                         661 m
# 14  2017-06-10 11:06:00                   ...                         661 m
# 15  2017-06-07 13:36:00                   ...                         569 m
# 16  2017-06-06 02:37:00                   ...                           9 m
# 17  2017-06-05 05:55:00                   ...                           NaN
# 18  2017-06-01 09:05:00                   ...                         911 m
#
#                                 operation_x airport_y  \
# 0                                       NaN      SBBR
# 1   VFR Diurno/Noturno e IFR Diurno/Noturno       NaN
# 2                                       NaN      SBGR
# 3   VFR Diurno/Noturno e IFR Diurno/Noturno       NaN
# 4                                       NaN       NaN
# 5   VFR Diurno/Noturno e IFR Diurno/Noturno       NaN
# 6                                       NaN       NaN
# 7                                       NaN       NaN
# 8                                       NaN      SBGR
# 9   VFR Diurno/Noturno e IFR Diurno/Noturno      SBBR
# 10  VFR Diurno/Noturno e IFR Diurno/Noturno       NaN
# 11  VFR Diurno/Noturno e IFR Diurno/Noturno      SBCF
# 12  VFR Diurno/Noturno e IFR Diurno/Noturno      SBGR
# 13  VFR Diurno/Noturno e IFR Diurno/Noturno      SBCT
# 14  VFR Diurno/Noturno e IFR Diurno/Noturno      SBLO
# 15  VFR Diurno/Noturno e IFR Diurno/Noturno      SBKP
# 16  VFR Diurno/Noturno e IFR Diurno/Noturno       NaN
# 17                                      NaN      SBGL
# 18  VFR Diurno/Noturno e IFR Diurno/Noturno      SBSP
#
#                                         airportname_y          city_y state_y  \
# 0                     PRESIDENTE JUSCELINO KUBITSCHEK        BRASÍLIA      DF
# 1                                                 NaN             NaN     NaN
# 2         GUARULHOS - GOVERNADOR ANDRÉ FRANCO MONTORO       GUARULHOS      SP
# 3                                                 NaN             NaN     NaN
# 4                                                 NaN             NaN     NaN
# 5                                                 NaN             NaN     NaN
# 6                                                 NaN             NaN     NaN
# 7                                                 NaN             NaN     NaN
# 8         GUARULHOS - GOVERNADOR ANDRÉ FRANCO MONTORO       GUARULHOS      SP
# 9                     PRESIDENTE JUSCELINO KUBITSCHEK        BRASÍLIA      DF
# 10                                                NaN             NaN     NaN
# 11                                     TANCREDO NEVES         CONFINS      MG
# 12        GUARULHOS - GOVERNADOR ANDRÉ FRANCO MONTORO       GUARULHOS      SP
# 13                                        AFONSO PENA        CURITIBA      PR
# 14                              GOVERNADOR JOSÉ RICHA        LONDRINA      PR
# 15                                          VIRACOPOS        CAMPINAS      SP
# 16                                                NaN             NaN     NaN
# 17  AEROPORTO INTERNACIONAL DO RIO DE JANEIRO/GALE...  RIO DE JANEIRO      RJ
# 18                                          CONGONHAS       SÃO PAULO      SP
#
#         latitude_y     longitude_y altitude_y  \
# 0   15° 52' 16'' S   47° 55' 7'' W     1066 m
# 1              NaN             NaN        NaN
# 2    23° 26' 8'' S  46° 28' 23'' W      750 m
# 3              NaN             NaN        NaN
# 4              NaN             NaN        NaN
# 5              NaN             NaN        NaN
# 6              NaN             NaN        NaN
# 7              NaN             NaN        NaN
# 8    23° 26' 8'' S  46° 28' 23'' W      750 m
# 9   15° 52' 16'' S   47° 55' 7'' W     1066 m
# 10             NaN             NaN        NaN
# 11  19° 37' 26'' S  43° 58' 17'' W      827 m
# 12   23° 26' 8'' S  46° 28' 23'' W      750 m
# 13  25° 31' 54'' S  49° 10' 34'' W      911 m
# 14  23° 19' 49'' S   51° 8' 12'' W      569 m
# 15   23° 0' 25'' S    47° 8' 4'' W      661 m
# 16             NaN             NaN        NaN
# 17  22° 48' 36'' S   43° 15' 2'' W        9 m
# 18  23° 37' 34'' S  46° 39' 23'' W      802 m
#
#                                 operation_y
# 0   VFR Diurno/Noturno e IFR Diurno/Noturno
# 1                                       NaN
# 2   VFR Diurno/Noturno e IFR Diurno/Noturno
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8   VFR Diurno/Noturno e IFR Diurno/Noturno
# 9   VFR Diurno/Noturno e IFR Diurno/Noturno
# 10                                      NaN
# 11  VFR Diurno/Noturno e IFR Diurno/Noturno
# 12  VFR Diurno/Noturno e IFR Diurno/Noturno
# 13  VFR Diurno/Noturno e IFR Diurno/Noturno
# 14  VFR Diurno/Noturno e IFR Diurno/Noturno
# 15  VFR Diurno/Noturno e IFR Diurno/Noturno
# 16                                      NaN
# 17  VFR Diurno/Noturno e IFR Diurno/Noturno
# 18  VFR Diurno/Noturno e IFR Diurno/Noturno
#
# [19 rows x 28 columns]
